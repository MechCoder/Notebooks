# %%
from skopt.benchmarks import branin, hart6
import numpy as np
from skopt import gp_minimize

# %%
bounds = [(-5.0, 10.0), (0.0, 15.0)]
n_calls = 200

branin_results = []
for random_state in range(10):
    res = gp_minimize(branin, bounds, n_random_starts=1, random_state=random_state, verbose=True, n_calls=n_calls)
    branin_results.append(res)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.0003
# Function value obtained: 73.0693
# Current minimum: 73.0693
# Iteration No: 2 started. Searching for the next optimal point.
# Iteration No: 2 ended. Search finished for the next optimal point.
# Time taken: 0.0504
# Function value obtained: 10.9717
# Current minimum: 10.9717
# Iteration No: 3 started. Searching for the next optimal point.
# Iteration No: 3 ended. Search finished for the next optimal point.
# Time taken: 0.1038
# Function value obtained: 10.9715
# Current minimum: 10.9715
# Iteration No: 4 started. Searching for the next optimal point.
# Iteration No: 4 ended. Search finished for the next optimal point.
# Time taken: 0.1697
# Function value obtained: 133.8322
# Current minimum: 10.9715
# Iteration No: 5 started. Searching for the next optimal point.
# Iteration No: 5 ended. Search finished for the next optimal point.
# ...

# %%
optimal_values = [result.fun for result in branin_results]
mean_optimum = np.mean(optimal_values)
std = np.std(optimal_values)
best = np.min(optimal_values)
print(mean_optimum)
print(std)
print(best)
# Out:
# 0.428759061943
# 0.0401254449564
# 0.398276814802

# %%
bounds = np.tile((0., 1.), (6, 1))
n_calls = 200

hart_results = []
for random_state in range(10):
    print(random_state)
    res = gp_minimize(hart6, bounds, n_random_starts=1, random_state=random_state, verbose=True, n_calls=n_calls)
    hart_results.append(res)
# Out:
# 0
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.0004
# Function value obtained: -0.3048
# Current minimum: -0.3048
# Iteration No: 2 started. Searching for the next optimal point.
# Iteration No: 2 ended. Search finished for the next optimal point.
# Time taken: 0.1671
# Function value obtained: -0.0001
# Current minimum: -0.3048
# Iteration No: 3 started. Searching for the next optimal point.
# Iteration No: 3 ended. Search finished for the next optimal point.
# Time taken: 0.4357
# Function value obtained: -0.3048
# Current minimum: -0.3048
# Iteration No: 4 started. Searching for the next optimal point.
# Iteration No: 4 ended. Search finished for the next optimal point.
# Time taken: 0.3069
# Function value obtained: -0.3294
# Current minimum: -0.3294
# Iteration No: 5 started. Searching for the next optimal point.
# Iteration No: 5 ended. Search finished for the next optimal point.
# ...

# %%
optimal_values = [result.fun for result in hart_results]
mean_optimum = np.mean(optimal_values)
std = np.std(optimal_values)
best = np.min(optimal_values)
print(mean_optimum)
print(std)
print(best)
# Out:
# -3.0460541186
# 0.258822455208
# -3.29940948752
